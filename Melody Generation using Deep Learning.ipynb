# %%
import os
import json
from tensorflow.keras.utils import to_categorical
import numpy as np
import keras

import os
import music21 as m21
from concurrent.futures import ProcessPoolExecutor
import multiprocessing

# %%
ACCEPTABLE_DURATIONS = [0.25,0.5,0.75,1,2,3,4]
SAVING_DIRECTORY = "dataset"
SINGLE_FILE_DATASET = "all_dataset"
MAPPING = "mapping.json"
SEQUENCES = 64
dataset_path = "/content/drive/MyDrive/deutschl/erk"
OUTPUT_UNITS = 38
NUM_UNITS = [256]
LOSS = "sparse_categorical_crossentropy"
LEARNING_RATE = 0.001
EPOCHS = 50
BATCH_SIZE = 64
SAVE_MODEL_PATH = "model.h5"

# %%
def load_song(file_path):
    try:
        print(f"Processing file: {file_path}")
        song = m21.converter.parse(file_path)
        print(f"Song converted: {file_path}")
        return song
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None


def load_songs(dataset_path):
    all_songs = []
    file_count = 0

    num_cores = multiprocessing.cpu_count()
    print(f"Number of CPU cores available: {num_cores}")

    with ProcessPoolExecutor(max_workers=num_cores) as executor:
        futures = []
        for path, subdir, files in os.walk(dataset_path):
            for file in files:
                if file.endswith(".krn"):
                    file_path = os.path.join(path, file)
                    futures.append(executor.submit(load_song, file_path))
                    file_count += 1

        print(f"Total MIDI files submitted for processing: {file_count}")

        success_count = 0
        for future in futures:
            result = future.result()
            if result:
                all_songs.append(result)
                success_count += 1

        print(f"Total MIDI files successfully processed: {success_count}")

    return all_songs
# Out:
# Number of CPU cores available: 2
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0595.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2046.krn
# Total MIDI files submitted for processing: 1700
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0595.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1053.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2046.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1124.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1124.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1211.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1053.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1401.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1211.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0950.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1401.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1574.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0950.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2040.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1574.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0603.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2040.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1004.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0603.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1978.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1004.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0792.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1978.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2241.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0792.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1062.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2241.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1062.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1580.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0641.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1580.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1773.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0641.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2120.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1773.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1654.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2120.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1945.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1945.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2137.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2137.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1654.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1347.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1441.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1347.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1441.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut2219.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1857.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2219.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1857.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0735.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2237.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2237.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0735.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1096.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1096.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1353.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0866.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1353.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1037.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0866.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0953.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1037.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1527.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0953.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2044.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1527.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0671.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2044.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0750.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0671.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1670.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0750.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1881.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1670.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0946.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1881.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2110.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0946.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1474.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut2110.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1830.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1474.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1285.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1830.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1223.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1285.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1223.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0822.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2243.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2243.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1768.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0822.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2048.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1768.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0801.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2048.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1880.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0801.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1724.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1880.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0820.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1724.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0820.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1313.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0785.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1313.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0785.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1276.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1617.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1276.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1617.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1310.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2026.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1310.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1045.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2026.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1688.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1688.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1045.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1337.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1634.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1337.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1713.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1634.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0811.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1713.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0811.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1291.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1647.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1647.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1291.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0823.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1022.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0823.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1657.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1022.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2245.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2245.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1114.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1114.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0646.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0646.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2013.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2013.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1710.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1710.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0960.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1657.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0960.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0651.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1582.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1582.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1911.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1911.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1897.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1897.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2080.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2080.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1164.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1164.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0651.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1424.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1035.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1424.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0922.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1035.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2167.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0922.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1977.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2167.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2077.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1977.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0805.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2077.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0829.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0805.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2108.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0829.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2019.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2108.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0860.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2019.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1477.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0860.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1477.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1613.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1971.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1613.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1060.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1971.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0837.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1060.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0837.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1090.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2060.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2060.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0662.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1090.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1069.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0662.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0927.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1069.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1205.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0927.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1392.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1205.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1878.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1392.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2239.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2239.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1023.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1878.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1417.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1023.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0720.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1417.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0931.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0720.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1116.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0931.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1701.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1116.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0944.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1701.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1845.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0944.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1511.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1845.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1196.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1511.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1327.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1196.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1327.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1152.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2109.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1152.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2109.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0917.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1259.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0917.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1259.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1235.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1133.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1235.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2075.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1133.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2075.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1962.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1944.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1962.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1944.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1800.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0826.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0826.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1800.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2028.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1021.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1021.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2028.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1236.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1576.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1236.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2143.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1576.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1577.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2143.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0975.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0975.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1357.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1357.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2192.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2192.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1212.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1212.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0640.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0640.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0790.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0790.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1352.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1352.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1400.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1400.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1505.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1505.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1987.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1987.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1058.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1058.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1786.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1786.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1384.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1384.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1762.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1762.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1642.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1642.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2189.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2189.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1673.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1673.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1995.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1995.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0858.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0858.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2228.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2228.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1545.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1545.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1564.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1564.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1161.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1161.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1284.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1284.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1429.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1429.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1948.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1948.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1459.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1459.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1100.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1100.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0739.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0739.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1303.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1303.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1779.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1779.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1999.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1999.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1649.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1649.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1266.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1266.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2008.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2008.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0693.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0693.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1290.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1290.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2246.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2246.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0700.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0700.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1821.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1821.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2063.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2063.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1239.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1239.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0731.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0731.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1955.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1955.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0590.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0590.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1061.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1061.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1896.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1896.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1922.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1922.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0609.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0609.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0674.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0674.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1659.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1659.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0952.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0952.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2005.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2005.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2138.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2138.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1799.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1799.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1683.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1683.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1904.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1904.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0718.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0718.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1126.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1126.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2194.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2194.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2032.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2032.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0715.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0715.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1942.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1942.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1793.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1793.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0757.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0757.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0737.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0737.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0596.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0596.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1572.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1572.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1273.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1273.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0639.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0639.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0780.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0780.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0701.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0701.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0608.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0608.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0882.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0882.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1703.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1703.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1298.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1298.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2055.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2055.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2117.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2117.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1806.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1806.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0967.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0967.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0728.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0728.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1847.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1847.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1050.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1050.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0748.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0748.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1559.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1559.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2045.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2045.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1871.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1871.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1872.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1872.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1598.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1598.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1498.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1498.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1359.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1359.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1097.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1097.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1484.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1484.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1844.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1844.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1385.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1385.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1707.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1707.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1856.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1856.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1457.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1457.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0855.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0855.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2264.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2264.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1562.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1562.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1227.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1227.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1916.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1916.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1454.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1454.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1354.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1354.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2094.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2094.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2113.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2113.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1258.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1258.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2179.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2179.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1283.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1283.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2127.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2127.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1837.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1837.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1231.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1231.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1129.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1129.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0600.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0600.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1171.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1171.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1577.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0833.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2129.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0833.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2129.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1640.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1056.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1056.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1640.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1016.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2265.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1016.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1491.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2265.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1509.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1491.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1509.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1811.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0647.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1811.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2226.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0647.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1506.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2226.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0865.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1506.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0865.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0592.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1664.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1664.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0616.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0592.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0964.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0616.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1219.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0964.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1219.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1342.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1483.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1342.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1832.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1483.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0679.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1832.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1825.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0679.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1462.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1825.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1389.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1462.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1551.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1389.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0861.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1551.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1452.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0861.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0902.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1452.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1195.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0902.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1195.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1859.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1727.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1859.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0996.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1727.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1626.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0996.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1185.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1185.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1836.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1836.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1450.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1450.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1626.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1244.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1612.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1612.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2018.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1244.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0968.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2018.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1849.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0968.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1068.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1849.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1029.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1068.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0758.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1029.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0758.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2217.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1892.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2217.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0809.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1892.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0770.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0809.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2099.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0770.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0571.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2099.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1458.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1458.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0571.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1769.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1935.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1935.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1071.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1769.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2011.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1071.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1921.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2011.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1921.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0954.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut2066.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2066.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0954.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1939.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0747.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1939.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0807.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0747.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0699.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0807.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0699.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0582.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0606.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0582.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1776.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0606.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0752.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1776.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0819.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0752.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1513.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0819.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1923.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1513.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0613.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0613.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1923.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0955.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1763.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0955.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0798.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1763.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0798.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1323.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0786.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0786.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1323.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1624.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2160.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1624.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2208.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2160.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2130.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2208.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1819.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2130.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1819.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0717.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1998.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0717.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2242.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1998.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1623.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut2242.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1756.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1623.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1093.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1756.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1065.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1093.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0979.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1065.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1533.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0979.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1057.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1057.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1813.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1533.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2159.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1813.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1840.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2159.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0625.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1840.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1295.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1295.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0625.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1419.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1972.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1419.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1646.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1972.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1900.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1900.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1646.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0696.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1870.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1870.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0696.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1616.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1675.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1675.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0813.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0813.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2182.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2182.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1192.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1192.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1039.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1616.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1749.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1039.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1749.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1829.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0795.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0795.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1829.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1655.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0581.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0581.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1655.krn
#
# ...
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1596.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1692.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1550.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1550.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0778.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1692.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0997.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0778.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1690.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0997.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1690.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1680.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1635.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1680.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0620.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1635.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1783.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0620.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0981.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1783.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2124.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2124.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0981.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1413.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0905.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0905.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1413.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2031.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1443.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1443.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1989.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2031.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1410.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1989.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0941.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1410.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2259.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0941.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1729.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2259.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1729.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1128.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2223.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2223.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1946.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1946.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2260.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2260.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1827.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1827.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1875.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1875.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1823.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1128.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1823.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1588.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1932.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1932.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1287.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1588.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1332.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1287.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1332.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0744.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0890.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0744.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1676.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0890.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1890.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1676.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1222.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1890.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1222.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2198.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0924.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2198.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1734.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0924.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0622.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0622.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1734.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0768.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1697.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0768.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1968.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1697.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0769.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1968.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1925.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0769.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1717.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1925.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2187.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1717.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1625.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2187.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1041.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1625.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0781.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0781.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1361.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1041.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1627.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1361.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1594.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1627.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1802.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1594.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1898.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1802.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1583.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1898.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1251.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1583.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1996.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1251.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1970.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1970.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1996.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0708.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1558.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0708.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1835.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1558.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1929.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1929.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0664.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0664.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1296.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1296.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0649.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0649.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0867.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1835.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1216.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0867.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1936.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1216.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0932.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1936.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0932.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1947.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1611.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1947.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1611.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1476.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1698.krn
#
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1698.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1476.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0816.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0695.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0816.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0961.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0695.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1706.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0961.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0904.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1706.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1421.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0904.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1421.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut0935.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0698.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0935.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1788.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0698.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2251.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1788.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1249.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut2251.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1862.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1249.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1862.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1054.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2231.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1054.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut2231.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1715.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1261.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1261.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1715.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1139.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1157.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1139.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1415.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1157.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1415.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1502.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0871.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1502.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0694.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut0871.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2205.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0694.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1994.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut2205.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0632.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0632.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1994.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1081.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1567.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1567.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1775.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1081.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1539.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1775.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0760.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1539.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1055.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0760.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1055.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2225.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1360.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2225.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2212.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1360.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1191.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2212.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0727.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1191.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1797.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0727.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2073.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1797.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1543.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2073.krnSong converted: /content/drive/MyDrive/deutschl/erk/deut1543.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1162.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2022.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2022.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1162.krnProcessing file: /content/drive/MyDrive/deutschl/erk/deut1173.krn
#
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1738.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1173.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1301.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1738.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut2016.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1301.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut1700.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut2016.krn
# Processing file: /content/drive/MyDrive/deutschl/erk/deut0880.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut1700.krn
# Song converted: /content/drive/MyDrive/deutschl/erk/deut0880.krn
# Total MIDI files successfully processed: 1700

# %%
def is_having_acceptable_durations(song, acceptable_durations):
  for note in song.flat.notesAndRests:
    if note.duration.quarterLength not in acceptable_durations:
      return False
  return True

# %%
def transpose_songs(song):
  parts = song.getElementsByClass(m21.stream.Part)
  measures_parts_zero = parts[0].getElementsByClass(m21.stream.Measure)
  key = measures_parts_zero[0][4]

  if not isinstance(key, m21.key.Key):
    key = song.analyze("key")

  if key.mode == "major":
    interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("C"))
  elif key.mode == "minor":
    interval = m21.interval.Interval(key.tonic, m21.pitch.Pitch("A"))

  tranposed_song = song.transpose(interval)
  return tranposed_song

# %%
def encoding_song(song, time_steps = 0.25):
  song_encoded = []
  for node in song.flat.notesAndRests:

    #notes
    if isinstance(node, m21.note.Note):
      sym = node.pitch.midi

    #rests
    elif isinstance(node, m21.note.Rest):
      sym = "r"

    #convert the node to time/series duration
    steps = int(node.duration.quarterLength/time_steps)
    for step in range(steps):
      if step == 0:
        song_encoded.append(sym)
      else:
        song_encoded.append("_")

  encoded_song = " ".join(map(str, song_encoded))
  return encoded_song

# %%
def preprocess_dataset(songs):
    print("Loading songs .........")
    songs = load_songs(dataset_path)
    print(f"Loaded {len(songs)} songs")
    if not os.path.exists(SAVING_DIRECTORY):
        os.makedirs(SAVING_DIRECTORY)

        # filter out songs that have non-acceptable durations
    for i,song in enumerate(songs):
      if not is_having_acceptable_durations(song, ACCEPTABLE_DURATIONS):
        pass

      # transpose songs to Cmaj/Amin
      song = transpose_songs(song)


      # encode the songs with music time series representation
      encoded_song = encoding_song(song)


      # save songs to text file
      save_path = os.path.join(SAVING_DIRECTORY, str(i))
      with open(save_path, "w") as fp:
        fp.write(encoded_song)

# %%
def load_file(file_path):
  with open(file_path, "r") as fp:
    song = fp.read()
  return song

# %%
def converge_data_to_single_file(dataset_path, store_all_dataset, sequences):
  deliminator = "/ " * sequences
  songs = ""

  for path, subdir, files in os.walk(dataset_path):
    for file in files:
      file_path = os.path.join(path, file)
      song = load_file(file_path)
      songs = songs + song + " " + deliminator

  songs = songs[:-1]

  with open(store_all_dataset, "w") as fp:
    fp.write(songs)

  return songs

# %%
def generate_mapping(songs, mappings):

  mapping = {}
  songs = songs.split()
  vocab = list(set(songs))

  for i, symbols in enumerate(vocab):
    mapping[symbols] = i

  with open(MAPPING, "w") as fp:
    json.dump(mapping, fp, indent = 4)

# %%
def converting_songs_to_int(songs):
  integer_songs = []

  with open(MAPPING, "r") as fp:
    mapping = json.load(fp)

  songs  = songs.split()
  for song in songs:
    integer_songs.append(mapping[song])

  return integer_songs

# %%
def generate_training_data(seq_length):
  songs = load_file(SINGLE_FILE_DATASET)
  int_songs = converting_songs_to_int(songs)

  inputs = []
  targets = []

  number_of_sequences  = len(int_songs)  - seq_length

  for i in range(number_of_sequences):
    inputs.append(int_songs[i:i+seq_length])
    targets.append(int_songs[i+seq_length])

  vocab_size  = len(set(int_songs))

  inputs = to_categorical(inputs, num_classes=vocab_size)
  targets = np.array(targets)

  return inputs,targets

# %%
def build_model(output_units, num_units, loss, learning_rate):
    input = keras.layers.Input(shape=(None, output_units))
    x = keras.layers.LSTM(num_units[0])(input)
    x = keras.layers.Dropout(0.2)(x)

    output = keras.layers.Dense(output_units, activation="softmax")(x)

    model = keras.Model(input, output)

    # compile model
    model.compile(loss=loss,
                  optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  metrics=["accuracy"])

    model.summary()

    return model


def train_data(output_units=OUTPUT_UNITS, num_units=NUM_UNITS, loss=LOSS, learning_rate=LEARNING_RATE):
  inputs, targets = generate_training_data(SEQUENCES)
  model = build_model(output_units, num_units, loss, learning_rate)

  # train the model
  model.fit(inputs, targets, epochs=EPOCHS, batch_size=BATCH_SIZE)

  # save the model
  model.save(SAVE_MODEL_PATH)

# %%
class MelodyGeneration:
  def __init__(self, model_path = SAVE_MODEL_PATH, mapping_path = MAPPING):
    self.model_path = model_path
    self.mapping_path = mapping_path
    self.model = keras.models.load_model(model_path)

    with open(mapping_path, "r") as fp:
      self._mapping = json.load(fp)

    self._start_symbols = ['/'] * SEQUENCES

  def melody_generate(self, song, num_steps, max_sequence_length, temp):
    song = song.split()
    mel = song
    song = self._start_symbols + song

    song = [self._mapping[sym] for sym in song]

    for i in range(num_steps):
      song = song[-max_sequence_length:]
      onehot_song = keras.utils.to_categorical(song, num_classes=len(self._mapping))
      onehot_song = onehot_song[np.newaxis, ...]
      _prediction = self.model.predict(onehot_song)[0]
      output_integers = self._sample_with_temperature(_prediction, temp)
      song.append(output_integers)
      output_symbol = [key for key, value in self._mapping.items() if value == output_integers][0]
      if output_symbol == "/":
        break
      mel.append(output_symbol)
      print(mel)
    return mel

  def _sample_with_temperature(self, _prediction, temp):
    predictions = np.log(_prediction) / temp
    _prediction = np.exp(predictions) / np.sum(np.exp(predictions))

    choices = range(len(_prediction))
    index = np.random.choice(choices, p=_prediction)

    return index

  def save_melody(self, mel, step_duration=0.25, format="midi", file_name="mel.mid"):
    stream = m21.stream.Stream()
    start_sym = None
    step_counter = 1

    for i, sym in enumerate(mel):
      if sym != "_" or i + 1 == len(mel):
        if start_sym is not None:
          quarter_length_time = step_duration * step_counter
          if start_sym == "r":
            m21_event = m21.note.Rest(quarterLength=quarter_length_time)
          else:
            m21_event = m21.note.Note(int(start_sym), quarterLength=quarter_length_time)
          stream.append(m21_event)
          step_counter = 1
        start_sym = sym
      else:
        step_counter += 1
    stream.write(format, file_name)

# %%
if __name__ == "__main__":
    songs = load_songs(dataset_path)
    preprocess_dataset(songs)
    songs = converge_data_to_single_file(SAVING_DIRECTORY, SINGLE_FILE_DATASET, SEQUENCES)
    generate_mapping(songs, MAPPING)
    train_data()
    mg = MelodyGeneration()
    seed = "67 _ 67 _ 65 67 _ _ 65 64 _ 64 _ 64 _ _"
    seed2 = "67 _ _ _ _ _ 65 _ 64 _ 62 _ 60 _ _ _"
    melody = mg.melody_generate(seed,500, SEQUENCES, 0.8)
    print(melody)
    mg.save_melody(melody)
# Out:
# 1/1 [==============================] - 0s 349ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71']
# 1/1 [==============================] - 0s 27ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73']
# 1/1 [==============================] - 0s 26ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71']
# 1/1 [==============================] - 0s 29ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71']
# 1/1 [==============================] - 0s 29ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55']
# 1/1 [==============================] - 0s 31ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67']
# 1/1 [==============================] - 0s 28ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71']
# 1/1 [==============================] - 0s 35ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51']
# 1/1 [==============================] - 0s 27ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71']
# 1/1 [==============================] - 0s 25ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67']
# 1/1 [==============================] - 0s 27ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71']
# 1/1 [==============================] - 0s 33ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67']
# 1/1 [==============================] - 0s 27ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67', '71']
# 1/1 [==============================] - 0s 29ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67', '71', '55']
# 1/1 [==============================] - 0s 31ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67', '71', '55', '66']
# 1/1 [==============================] - 0s 26ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67', '71', '55', '66', '81']
# 1/1 [==============================] - 0s 26ms/step
# ['67', '_', '67', '_', '65', '67', '_', '_', '65', '64', '_', '64', '_', '64', '_', '_', '71', '73', '71', '71', '55', '67', '71', '51', '71', '67', '71', '67', '71', '55', '66', '81']
